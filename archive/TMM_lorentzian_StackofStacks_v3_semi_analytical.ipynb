# %%
# 1. interpolation w.r.t. n instead of e
# 2. added semi-analytical calculation

import tmm

from numpy import pi, inf
import numpy as np
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt
# %matplotlib inline
#%matplotlib qt
#plt.rcParams['figure.figsize'] = [3,2]


# Load external plotting functions
from plot_functions import plot_setup, plot, legend

# Load plotting colors
import colors # make available colors from schmid_colors.py 

# Image file settings
fmt = '.png' # image format (use png for PowerPoint, pdf and eps for publications)
dpi = 300 # image resolution, density of pixels per inch (use at least 300)
fig_dir = 'C:\\Users\\kl89\\MS Window Project\\Figures\\'

degree = pi/180

# %%
# Lorentzian dielectric function for spatial KK stack
def eps(x, a, gam, nb):
    return nb**2 - a * gam / (x + 1j*gam)

# %%
def generate_n_and_d_old(gam, a, nb, plot_flag):

    del_n   = np.sqrt(a)/50                # Max e-step size in discrete Lorentzian approximation
    del_x   = 10*gam                # Max x-step size in discrete Lorentzian approximation
    dx      = gam/100               # Step size in 'continuous' Lorentzian
    xmin    = -gam * 200           # Limits of Lorentzian
    xmax    = - xmin

    nx      = 1 + int(np.floor((xmax - xmin) / dx))
    xx      = np.linspace(xmin, xmax, nx)
    ee      = eps(xx,a,gam,nb)                    # Smooth Lorentzian curve
    nk      = np.sqrt(ee)

    xq      = [xx[0]]                               
    nq      = [nb]
    count = 0
    for k in range(0,nx):
        if abs((nk[k]) - (nq[count])) > del_n or abs((xx[k]) - (xq[count])) > del_x:
            xq.append(xx[k])
            nq.append(nk[k])
            count = count + 1

    xq = np.append(xq,xmax)
    nq = np.append(nq,nb)
    midpoints = (xq[:-1] + xq[1:]) / 2
    d_list = np.diff(midpoints)
    n_list  = nq[1:-1]

    #midpoints = np.insert(midpoints,0,xq[0]); midpoints = np.append(midpoints,xq[-1])
    #d_list = np.insert(d_list,0,inf); d_list = np.append(d_list,inf)          # Append super- & sub-strate
    #n_list = np.insert(n_list,0,nb); n_list = np.append(n_list,nb)

    
    # plot imaginary and real part of refractive index
    if (plot_flag):
        plt.figure()
        plt.plot(xx/gam, np.real(nk), label='smooth')
        plt.step(xq/gam, np.real(nq), where='mid', label='discrete')
        plt.plot((midpoints[1:] + midpoints[:-1])/2/gam, np.real(n_list), '*', label='inputs')
        plt.xlabel('x/x0')
        plt.ylabel('Refractive Index')
        plt.title(f'Real Part of Refractive Index from A={a}, x0={gam}')
        #plt.xlim([-5, 5])
        plt.legend(loc='upper right')

        plt.figure()
        plt.plot(xx/gam, np.imag(nk), label='smooth')
        plt.step(xq/gam, np.imag(nq), where='mid', label='discrete')
        plt.plot((midpoints[1:] + midpoints[:-1])/2/gam, np.imag(n_list), '*', label='inputs')
        plt.xlabel('x/x0')
        plt.ylabel('Refractive Index')
        plt.title(f'Imaginary Part of Refractive Index from A={a}, x0={gam}')
        plt.legend(loc='upper right')
        #plt.xlim([-5, 5])

        plt.show()
    

    return (n_list.tolist(), d_list.tolist())

# %%
def generate_n_and_d(gam, a, nb, plot_flag):    
    
    dx      = gam/100               # Step size in 'continuous' Lorentzian
    xmin    = -gam * 200           # Limits of Lorentzian
    xmax    = - xmin

    nx      = 1 + int(np.floor((xmax - xmin) / dx))
    xx      = np.linspace(xmin, xmax, nx)
    ee      = eps(xx,a,gam,nb)                    # Smooth Lorentzian curve
    nk      = np.sqrt(ee)

    k_max   = np.max(np.imag(nk))     # Max k value. used to set max n-step size 
    del_n   = k_max/15                # Max n-step size in discrete Lorentzian approximation
    del_x   = 25*gam                # Max x-step size in discrete Lorentzian approximation

    xq      = [xx[0]]                               
    nq      = [nk[0]]
    count   = 0
    for k in range(0,nx):
        if abs((nk[k]) - (nq[count])) > del_n or abs((xx[k]) - (xq[count])) > del_x:
            xq.append(xx[k])
            nq.append(nk[k])
            count = count + 1

    xq = np.append(xq,xmax)     # should we be appending xx[-1]? because xx does not include xmax as it is rn
    nq = np.append(nq,nk[-1])
    midpoints = (xq[:-1] + xq[1:]) / 2
    d_list = np.diff(midpoints)
    n_list  = nq[1:-1]

    d_list2 = np.diff(xq)
    n_list2 = (nq[:-1] + nq[1:]) / 2

    #midpoints = np.insert(midpoints,0,xq[0]); midpoints = np.append(midpoints,xq[-1])
    #d_list = np.insert(d_list,0,inf); d_list = np.append(d_list,inf)          # Append super- & sub-strate
    #n_list = np.insert(n_list,0,nb); n_list = np.append(n_list,nb)

    
    # plot imaginary and real part of refractive index
    if (plot_flag):

        savename = f'Ref_index_real_A~{a}_gam~{gam}'
        xlabel = 'x/x$_0$'; ylabel = 'Refractive Index'
        title = f'Real Refractive Index (A={a}, x$_0$={gam})'
        fig,ax = plot_setup(xlabel,ylabel,title=title,figsize=(5,4),auto_scale=True)

        plot(fig,ax,xx/gam,np.real(nk), label='smooth', linewidth=1, color=colors.red,auto_scale=True)
        ax.stairs(np.real(n_list2), xq/gam, baseline=nb, label='discrete')
        plot(fig,ax,(xq[1:] + xq[:-1])/2/gam, np.real(n_list2), '*', markersize=5, label='inputs', color=colors.green,auto_scale=True)

        plt.savefig(fig_dir+savename+fmt,bbox_inches='tight',transparent=False,dpi=dpi)
        legend(fig,ax,auto_scale=True) # create legend from curves labeled above
        plt.savefig(fig_dir+savename+'legend'+fmt, bbox_inches='tight', transparent=True, dpi=dpi) # save legend as image file

        savename = f'Ref_index_imag_A~{a}_gam~{gam}'
        xlabel = 'x/x$_0$'; ylabel = 'Refractive Index'
        title = f'Imaginary Refractive Index (A={a}, x$_0$={gam})'
        fig,ax = plot_setup(xlabel,ylabel,title=title,figsize=(5,4),auto_scale=True)

        plot(fig,ax,xx/gam,np.imag(nk), label='smooth', linewidth=1, color=colors.red,auto_scale=True)
        ax.stairs(np.imag(n_list2), xq/gam, baseline=0, label='discrete')
        plot(fig,ax,(xq[1:] + xq[:-1])/2/gam, np.imag(n_list2), '*', markersize=5, label='inputs', color=colors.green,auto_scale=True)

        plt.savefig(fig_dir+savename+fmt,bbox_inches='tight',transparent=False,dpi=dpi)
        legend(fig,ax,auto_scale=True) # create legend from curves labeled above
        plt.savefig(fig_dir+savename+'legend'+fmt, bbox_inches='tight', transparent=True, dpi=dpi) # save legend as image file

        '''
        fig, ax = plt.subplots()
        ax.plot(xx/gam, np.real(nk), label='smooth')
        #plt.step(xq/gam, np.real(nq), where='pre', label='discrete')
        #plt.step((xq[1:] + xq[:-1])/2/gam, np.real(n_list2), where='mid', label='discrete')
        ax.stairs(n_list2, xq/gam, baseline=nb)
        #plt.plot((midpoints[1:] + midpoints[:-1])/2/gam, np.real(n_list), '*', label='inputs')
        ax.plot((xq[1:] + xq[:-1])/2/gam, np.real(n_list2), '+', label='inputs2')
        plt.xlabel('x/x0')
        plt.ylabel('Refractive Index')
        plt.title(f'Real Part of Refractive Index from A={a}, x0={gam}')
        #plt.xlim([-5, 5])
        plt.legend(loc='upper right')

        plt.figure()
        plt.plot(xx/gam, np.imag(nk), label='smooth')
        plt.step(xq/gam, np.imag(nq), where='mid', label='discrete')
        plt.plot((midpoints[1:] + midpoints[:-1])/2/gam, np.imag(n_list), '*', label='inputs')
        plt.plot((xq[1:] + xq[:-1])/2/gam, np.imag(n_list2), '+', label='inputs2')
        plt.xlabel('x/x0')
        plt.ylabel('Refractive Index')
        plt.title(f'Imaginary Part of Refractive Index from A={a}, x0={gam}')
        plt.legend(loc='upper right')
        #plt.xlim([-5, 5])

        plt.show()
        '''
    

    return (n_list2.tolist(), d_list2.tolist())

# %%
A = 5
gam = 0.001
nb = 1.7
n_list, d_list = generate_n_and_d(gam, A, nb, True)
print(len(n_list))
print(np.sum(d_list))
# Out:
# 60
# 0.4

# %%
def generate_StackofStacks(gam, a, nb, num_stacks, t_prop):
    n_list = []
    d_list = []
    c_list = []
    c_list_KK = []

    n_list_KK, d_list_KK = generate_n_and_d(gam, a, nb, True)
    t_KK = np.sum(d_list_KK)
    t_inc = t_prop*t_KK
    print(f"t_KK is: {t_KK}")
    print(f"t_inc is: {t_inc}")
    t_total = num_stacks*(t_inc + t_KK)
    print(f"t_total is: {t_total}")
    #print(f'length of KK MS is: {t_KK}')

    k_bulk = np.sum(d_list_KK * np.imag(n_list_KK)) / t_KK
    print(f'k_bulk from np.sum is: {k_bulk}')
    losses_total = t_total * k_bulk
    print(f'total losses are: {losses_total}')

    for i in range(len(d_list_KK)):
        c_list_KK.append('c')

    for i in range(num_stacks):
        n_list.extend(n_list_KK)
        d_list.extend(d_list_KK)
        c_list.extend(c_list_KK)
        n_list.append(nb)
        d_list.append(t_inc)
        c_list.append('i')
    
    d_list.append(inf)
    d_list.insert(0, inf)
    n_list.append(nb)
    n_list.insert(0, nb)
    c_list.insert(0, 'i')
    c_list.append('i')


    return (n_list, d_list, c_list, losses_total)

# %%
# wavelength dependence calculation of RTA using incoherent TMM function (inc_tmm)

def TRA_func(n_list, d_list, c_list):
    pol = 'p'
    lambda_list = np.linspace(2,5,100)
    angle = 0
    T_list = np.zeros_like(lambda_list)
    R_list = np.zeros_like(lambda_list)
    A_list = np.zeros_like(lambda_list)
    
    for j, lamb in enumerate(lambda_list):
        T_list[j] = tmm.inc_tmm(pol, n_list, d_list, c_list, angle, lamb)['T']
        R_list[j] = tmm.inc_tmm(pol, n_list, d_list, c_list, angle, lamb)['R']
      #  T_list[j] = tmm.coh_tmm(pol, n_list, d_list, angle, lamb)['T']
      #  R_list[j] = tmm.coh_tmm(pol, n_list, d_list, angle, lamb)['R']
        A_list[j] = 1 - T_list[j] - R_list[j]

    return (T_list, R_list, A_list)

# %%
nkdata_sapphire = np.genfromtxt('lam_um_T_K_Al2O3_no_ko_ne_ke.dat')
kdata_sapphire = nkdata_sapphire[:451, 3]
ndata_sapphire = nkdata_sapphire[:451, 2]
lamdata_sapphire = nkdata_sapphire[:451, 0]
plt.figure(lamdata_sapphire, ndata_sapphire)
plt.plot(lamdata_sapphire, kdata_sapphire)
k_bulk = np.average(kdata_sapphire)
print(k_bulk)
n_list, d_list, c_list, losses_total = generate_StackofStacks(0.01, 0.01, 1.7, 2, 0)
print(n_list)
print(d_list)
print(c_list)
# Out:
# 4.268238205980066e-06
# t_KK is: 19.72175
# t_inc is: 0.0
# t_total is: 39.4435
# k_bulk from np.sum is: 4.783392186631738e-06
# total losses are: 0.00018867372971340896
# [1.7, (1.7000030321347646+3.125909340822993e-09j), (1.7000031289380046+3.3286898003126126e-09j), (1.7000032320905976+3.551783563662285e-09j), (1.700003342276368+3.798080753971135e-09j), (1.7000034602807197+4.07101013932425e-09j), (1.7000035868789403+4.374344686703928e-09j), (1.7000037231395329+4.7130086661510464e-09j), (1.700003870161627+5.092580164417974e-09j), (1.7000040292725052+5.5199229127321635e-09j), (1.7000042019670438+6.003231446385206e-09j), (1.7000043901933302+6.553105743200021e-09j), (1.7000045960734964+7.1821406772387635e-09j), (1.700004822134332+7.906034287485178e-09j), (1.7000050716708128+8.745453248319652e-09j), (1.7000053484426867+9.726017481615722e-09j), (1.7000056571661772+1.0881240170344727e-08j), (1.700006003713123+1.2255205294525049e-08j), (1.7000063954880216+1.3906836547408005e-08j), (1.700006841963002+1.591632175659513e-08j), (1.7000073554536905+1.8395032706454036e-08j), (1.7000079522727867+2.150129562552837e-08j), (1.7000086542401631+2.5464817227614308e-08j), (1.700009492440042+3.063650122684011e-08j), (1.7000105104163907+3.755988957533733e-08j), (1.7000117729531694+4.7125580032837316e-08j), (1.7000133802102935+6.087146916344096e-08j), (1.7000154956871667+8.164181529528502e-08j), (1.700018404539287+1.1517171250738099e-07j), (1.7000226595445256+1.7458504894493102e-07j), (1.7000294704444863+2.953220665569633e-07j), (1.7000421340636767+6.03718891552644e-07j), (1.7000738877623378+1.8573694240022061e-06j), (1.7001911575831605+1.2476944593309769e-05j), (1.7003071259047968+3.242849604349654e-05j), (1.7004215375044134+6.171070785984849e-05j), (1.7005329713125685+9.997839646806558e-05j), (1.7006420795362722+0.00014757515501301682j), (1.700745870513476+0.0002031866004395575j), (1.7008458379499152+0.0002675970189048071j), (1.7009417580331043+0.00034110982565268845j), (1.7010317905486443+0.00042271520487506824j), (1.7011143358491023+0.00051096061066686j), (1.7011903529672714+0.0006070552043563341j), (1.7012556306175617+0.0007050680603158314j), (1.7013143045407362+0.0008108664451846294j), (1.7013640895636726+0.0009211441656891157j), (1.7014064998895306+0.0010411851519521104j), (1.7014369950245203+0.0011580597492801032j), (1.701457909240906+0.001277898894392867j), (1.701468779680234+0.0013976872879397362j), (1.7014694165501114+0.001529265415770526j), (1.701458834560213+0.0016561399342825004j), (1.7014388492444312+0.0017744636297327735j), (1.7014068305816983+0.001898904445721568j), (1.7013607235753663+0.0020283140040034085j), (1.701308416450187+0.0021419098573258566j), (1.7012429986112663+0.002256451075022172j), (1.7011633994534145+0.0023701032540037643j), (1.7010856507621879+0.002462549749342952j), (1.70099724643845+0.0025513862878631956j), (1.7008981835048351+0.0026350155436301263j), (1.7007887533695578+0.002711753969409068j), (1.700669578954242+0.0027798964500628663j), (1.7005416351587193+0.002837795274594345j), (1.7004062469432606+0.0028839484004750367j), (1.70026506109662+0.0029170895336439557j), (1.7001199906797462+0.00293627085553934j), (1.6999731348058262+0.0029409288580116615j), (1.6998266801569617+0.002930925032366671j), (1.6996827936242869+0.002906556044824561j), (1.6995435169696265+0.0028685320258777856j), (1.6994106740593466+0.0028179258875768356j), (1.6992857991040036+0.0027561002544121134j), (1.6991700909810428+0.0026846209293208308j), (1.699064394910876+0.0026051664800480975j), (1.6989692092942565+0.002519442622645653j), (1.6988847129849234+0.002429108038643732j), (1.6988108069276782+0.0023357156878652356j), (1.6987356250784802+0.0022215756650434686j), (1.6986743224245553+0.0021071456942833903j), (1.6986257670721703+0.0019941440008945676j), (1.6985835385193657+0.0018658906817837467j), (1.6985548553238448+0.0017429562722048755j), (1.6985376855845318+0.0016263583449876576j), (1.6985297392099639+0.0015015927240498318j), (1.698532692060414+0.0013724263409251353j), (1.6985453026779496+0.0012549861030967835j), (1.6985676074585552+0.0011376011548221644j), (1.6985991218131535+0.0010231854197676902j), (1.69864 ...
# [inf, 0.3000500000000006, 0.3000499999999988, 0.3000000000000007, 0.3000499999999988, 0.3000500000000006, 0.3000500000000006, 0.3001000000000005, 0.3000999999999987, 0.3000500000000006, 0.3000500000000006, 0.3000999999999987, 0.3000500000000006, 0.3000500000000006, 0.3000999999999996, 0.3000999999999996, 0.3001000000000005, 0.3001000000000005, 0.3000999999999996, 0.3000999999999996, 0.30010000000000003, 0.30005000000000015, 0.30005000000000015, 0.30010000000000003, 0.30010000000000003, 0.30010000000000003, 0.30010000000000003, 0.30005000000000015, 0.3000499999999997, 0.3000499999999997, 0.3000000000000007, 0.3000499999999997, 0.2723499999999994, 0.1515500000000003, 0.04245000000000054, 0.02069999999999972, 0.012399999999999523, 0.008300000000000196, 0.005950000000000344, 0.004550000000000054, 0.0035999999999996035, 0.0029000000000003467, 0.002400000000000624, 0.0019999999999997797, 0.0016999999999995907, 0.0015000000000000568, 0.0013500000000004064, 0.0011999999999998678, 0.0010499999999993292, 0.0009499999999995623, 0.000900000000000567, 0.0008500000000006835, 0.0007500000000000284, 0.000700000000000145, 0.0006999999999992568, 0.0006499999999993733, 0.000600000000000378, 0.000600000000000378, 0.0005499999999996064, 0.0004999999999997229, 0.0005000000000006111, 0.0004999999999997229, 0.0004999999999997229, 0.0005000000000006111, 0.0004999999999997229, 0.0004999999999997229, 0.0005000000000006111, 0.0004999999999997229, 0.0004999999999997229, 0.0005000000000006111, 0.0004999999999997229, 0.0004999999999997229, 0.0005000000000006111, 0.0004999999999997229, 0.0004999999999997229, 0.0005000000000006111, 0.0004999999999997229, 0.0004999999999997229, 0.0005500000000004945, 0.000600000000000378, 0.0005999999999994898, 0.0006499999999993733, 0.000700000000000145, 0.000700000000000145, 0.0007500000000000284, 0.0008499999999997954, 0.0008999999999996788, 0.0009500000000004505, 0.0010500000000002174, 0.0011999999999998678, 0.0013500000000004064, 0.0015000000000000568, 0.0017499999999994742, 0.002049999999999663, 0.002400000000000624, 0.0029000000000003467, 0.0035999999999996035, 0.0045999999999999375, 0.006099999999999994, 0.00849999999999973, 0.012750000000000483, 0.02150000000000052, 0.044950000000000045, 0.17264999999999997, 0.2914999999999992, 0.3000499999999997, 0.3000000000000007, 0.3000499999999997, 0.3000499999999997, 0.3000000000000007, 0.3000499999999997, 0.3000499999999997, 0.3000000000000007, 0.3000499999999997, 0.3000499999999997, 0.3000000000000007, 0.3000499999999997, 0.3000499999999997, 0.3000500000000006, 0.3000999999999996, 0.3000499999999997, 0.3000000000000007, 0.3000499999999997, 0.3000499999999997, 0.3000000000000007, 0.3000000000000007, 0.3000499999999988, 0.3000499999999988, 0.3000000000000007, 0.3000000000000007, 0.3000000000000007, 0.3000500000000006, 0.3000999999999987, 0.3000499999999988, 0.3000000000000007, 0.2782499999999999, 0.0, 0.3000500000000006, 0.3000499999999988, 0.3000000000000007, 0.3000499999999988, 0.3000500000000006, 0.3000500000000006, 0.3001000000000005, 0.3000999999999987, 0.3000500000000006, 0.3000500000000006, 0.3000999999999987, 0.3000500000000006, 0.3000500000000006, 0.3000999999999996, 0.3000999999999996, 0.3001000000000005, 0.3001000000000005, 0.3000999999999996, 0.3000999999999996, 0.30010000000000003, 0.30005000000000015, 0.30005000000000015, 0.30010000000000003, 0.30010000000000003, 0.30010000000000003, 0.30010000000000003, 0.30005000000000015, 0.3000499999999997, 0.3000499999999997, 0.3000000000000007, 0.3000499999999997, 0.2723499999999994, 0.1515500000000003, 0.04245000000000054, 0.02069999999999972, 0.012399999999999523, 0.008300000000000196, 0.005950000000000344, 0.004550000000000054, 0.0035999999999996035, 0.0029000000000003467, 0.002400000000000624, 0.0019999999999997797, 0.0016999999999995907, 0.0015000000000000568, 0.0013500000000004064, 0.0011999999999998678, 0.0010499999999993292, 0.0009499999999995623, 0.000900000000000567, 0.0008500000000006835, 0.0007500000000000284, 0.0 ...
# ['i', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'i', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'i', 'i']

# %%
# calculate TRA of stack of stacks

#A = 0.00178063
A = 5
gam = 0.001
nb = 1.7
num_stacks = 2
t_prop = 0

n_list, d_list, c_list, losses_total = generate_StackofStacks(gam, A, nb, num_stacks, t_prop)

n_list_reversed = n_list[::-1]
d_list_reversed = d_list[::-1]
c_list_reversed = c_list[::-1]

T_list_LR, R_list_LR, A_list_LR = TRA_func(n_list, d_list, c_list)
T_list_RL, R_list_RL, A_list_RL = TRA_func(n_list_reversed, d_list_reversed, c_list_reversed)
lambda_list = np.linspace(2,5,100)

trans_bulk = np.exp(-4*np.pi*losses_total/lambda_list)
emiss_bulk = 1 - trans_bulk

n_list_KK, d_list_KK = generate_n_and_d(gam, A, nb, False)
c_list_KK = []
for i in range(len(d_list_KK)):
    c_list_KK.append('c')

d_list_KK.append(inf)
d_list_KK.insert(0, inf)
n_list_KK.append(nb)
n_list_KK.insert(0, nb)
c_list_KK.insert(0, 'i')
c_list_KK.append('i')

n_list_reversed_KK = n_list_KK[::-1]
d_list_reversed_KK = d_list_KK[::-1]
c_list_reversed_KK = c_list_KK[::-1]


T_list_LR_KK, R_list_LR_KK, A_list_LR_KK = TRA_func(n_list_KK, d_list_KK, c_list_KK)
T_list_RL_KK, R_list_RL_KK, A_list_RL_KK = TRA_func(n_list_reversed_KK, d_list_reversed_KK, c_list_reversed_KK)
print(R_list_LR_KK)

T_list_analytic = T_list_LR_KK**num_stacks
geom_series = np.zeros_like(A_list_LR_KK)
for k in range(num_stacks):
    geom_series = geom_series + T_list_LR_KK**k
    
A_list_LR_analytic = A_list_LR_KK*geom_series
A_list_RL_analytic = A_list_RL_KK*geom_series
# Out:
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 0.8
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.009469530995511817
# [1.60809696e-06 1.26490516e-06 9.71081348e-07 7.23245899e-07
#  5.18096360e-07 3.52431423e-07 2.23168749e-07 1.27357680e-07
#  6.21877459e-08 2.49937410e-08 1.32580199e-08 2.46105697e-08
#  5.68273224e-08 1.07827096e-07 1.75667492e-07 2.58540010e-07
#  3.54764617e-07 4.62783928e-07 5.81157173e-07 7.08554048e-07
#  8.43748556e-07 9.85612907e-07 1.13311154e-06 1.28529532e-06
#  1.44129590e-06 1.60032034e-06 1.76164597e-06 1.92461543e-06
#  2.08863207e-06 2.25315549e-06 2.41769743e-06 2.58181784e-06
#  2.74512121e-06 2.90725316e-06 3.06789716e-06 3.22677161e-06
#  3.38362699e-06 3.53824325e-06 3.69042741e-06 3.84001130e-06
#  3.98684945e-06 4.13081720e-06 4.27180883e-06 4.40973596e-06
#  4.54452601e-06 4.67612072e-06 4.80447492e-06 4.92955526e-06
#  5.05133911e-06 5.16981353e-06 5.28497437e-06 5.39682529e-06
#  5.50537709e-06 5.61064686e-06 5.71265737e-06 5.81143644e-06
#  5.90701635e-06 5.99943333e-06 6.08872708e-06 6.17494036e-06
#  6.25811853e-06 6.33830925e-06 6.41556210e-06 6.48992830e-06
#  6.56146043e-06 6.63021219e-06 6.69623814e-06 6.75959351e-06
#  6.82033403e-06 6.87851575e-06 6.93419485e-06 6.98742756e-06
#  7.03827001e-06 7.08677811e-06 7.13300745e-06 7.17701325e-06
#  7.21885021e-06 7.25857253e-06 7.29623375e-06 7.33188677e-06
#  7.36558379e-06 7.39737624e-06 7.42731477e-06 7.45544920e-06
#  7.48182852e-06 7.50650086e-06 7.52951345e-06 7.55091266e-06
#  7.57074392e-06 7.58905176e-06 7.60587982e-06 7.62127080e-06
#  7.63526647e-06 7.64790773e-06 7.65923452e-06 7.66928592e-06
#  7.67810007e-06 7.68571425e-06 7.69216485e-06 7.69748739e-06]

# %%
np.savetxt(f"C:\\Users\\kl89\\MS Window Project\\Data\\T_list_RL_A={A}_x0={gam}_N={num_stacks}.txt", T_list_RL)
np.savetxt(f"C:\\Users\\kl89\\MS Window Project\\Data\\T_list_analytic_A={A}_x0={gam}_N={num_stacks}.txt", T_list_analytic)
np.savetxt(f"C:\\Users\\kl89\\MS Window Project\\Data\\A_list_RL_A={A}_x0={gam}_N={num_stacks}.txt", A_list_RL)
np.savetxt(f"C:\\Users\\kl89\\MS Window Project\\Data\\A_list_RL_analytic_A={A}_x0={gam}_N={num_stacks}.txt", A_list_RL_analytic)

# %%
# plotting RTA forwards and backwards

savename = f'Abs_diff_A={A}_x0={gam}_N={num_stacks}'
xlabel = 'Wavelength ($\mu$m)'; ylabel = 'Fraction of Power'
title = f'Error in Absorbance (A={A}, x$_0$={gam}, N={num_stacks})'
fig,ax = plot_setup(xlabel,ylabel,title=title,xmin=lambda_list[0],xmax=lambda_list[-1],xstep=1,figsize=(5,4),auto_scale=True)
#plt.rcParams['figure.figsize'] = [2,1]
#plot(fig,ax,lambda_list,T_list_RL,label=r'T$_{RL}$',color=colors.green,auto_scale=True)
#plot(fig,ax,lambda_list,T_list_analytic, '--', label=r'T$_{analytic}$',color=colors.light_blue,auto_scale=True)
#plot(fig,ax,lambda_list,trans_bulk, '--', label=r'trans_bulk',color=colors.red,auto_scale=True)
small_term = A_list_LR_KK*R_list_RL_KK*T_list_LR_KK
plot(fig,ax,lambda_list,A_list_RL-A_list_RL_analytic,label=r'A$_{{TMM}}$ - A$_{{analytic}}$',color=colors.blue,auto_scale=True)
plot(fig,ax,lambda_list,small_term, '--', label=r'A$_{LR}$R$_{RL}$T',color=colors.light_red,auto_scale=True)
#plot(fig,ax,lambda_list,A_list_RL_analytic, '--', label=r'A$_{RL,analytic}$',color=colors.light_red,auto_scale=True)
#plot(fig,ax,lambda_list,emiss_bulk, '--', label=r'emiss_bulk',color=colors.light_purple,auto_scale=True)

#plot(fig,ax,lambda_list,R_list_RL,label=r'R$_{RL}$',color=colors.purple,auto_scale=True)
#plot(fig,ax,lambda_list,R_list_LR, '--', label=r'R$_{LR}$',color=colors.light_purple,auto_scale=True)

plt.savefig(fig_dir+savename+fmt,bbox_inches='tight',transparent=False,dpi=dpi) # save figure as image file

# Create and save legend for above figure
legend(fig,ax,auto_scale=True) # create legend from curves labeled above
plt.savefig(fig_dir+savename+'legend'+fmt, bbox_inches='tight', transparent=True, dpi=dpi) # save legend as image file


'''
plt.figure()
#plt.plot(lambda_list,T_list_LR, label='T_LR')
#print(T_list_LR/trans_bulk)
plt.plot(lambda_list,T_list_RL, label='T_RL')
plt.plot(lambda_list,T_list_analytic, '--', label='T_analytic')
#plt.plot(lambda_list,T_list_LR_KK, label='T_LR_KK')
#plt.plot(lambda_list,R_list_LR, label='R_LR')
#plt.plot(lambda_list,A_list_LR, label='A_LR')
#plt.plot(lambda_list,R_list_RL, label='R_RL')
plt.plot(lambda_list,A_list_RL, label='A_RL')
plt.plot(lambda_list,A_list_RL_analytic, '--', label='A_RL_analytic')
#plt.plot(lambda_list,A_list_LR_analytic, '--', label='A_LR_analytic')
#plt.plot(lambda_list,trans_bulk, '--', label='T_bulk')
#plt.plot(lambda_list,emiss_bulk, '--', label='A_bulk')
plt.xlabel('Wavelength ($\mu$m)')
plt.ylabel('Fraction of Power')
plt.title(f'Transmittance and Emittance for N={num_stacks}')
plt.legend(loc='center right')
'''
# Out:
# "\nplt.figure()\n#plt.plot(lambda_list,T_list_LR, label='T_LR')\n#print(T_list_LR/trans_bulk)\nplt.plot(lambda_list,T_list_RL, label='T_RL')\nplt.plot(lambda_list,T_list_analytic, '--', label='T_analytic')\n#plt.plot(lambda_list,T_list_LR_KK, label='T_LR_KK')\n#plt.plot(lambda_list,R_list_LR, label='R_LR')\n#plt.plot(lambda_list,A_list_LR, label='A_LR')\n#plt.plot(lambda_list,R_list_RL, label='R_RL')\nplt.plot(lambda_list,A_list_RL, label='A_RL')\nplt.plot(lambda_list,A_list_RL_analytic, '--', label='A_RL_analytic')\n#plt.plot(lambda_list,A_list_LR_analytic, '--', label='A_LR_analytic')\n#plt.plot(lambda_list,trans_bulk, '--', label='T_bulk')\n#plt.plot(lambda_list,emiss_bulk, '--', label='A_bulk')\nplt.xlabel('Wavelength ($\\mu$m)')\nplt.ylabel('Fraction of Power')\nplt.title(f'Transmittance and Emittance for N={num_stacks}')\nplt.legend(loc='center right')\n"

# %%
# calculate FOM_KK and equivalently lossy bulk

delta_lamb = lambda_list[-1] - lambda_list[0]
FOM_LR = (np.trapz(T_list_LR, x=lambda_list))**2 / np.trapz(A_list_LR, x=lambda_list) / delta_lamb
FOM_RL = (np.trapz(T_list_RL, x=lambda_list))**2 / np.trapz(A_list_RL, x=lambda_list) / delta_lamb
FOM_RL_analytic = (np.trapz(T_list_analytic, x=lambda_list))**2 / np.trapz(A_list_RL_analytic, x=lambda_list) / delta_lamb
FOM_bulk = (np.trapz(trans_bulk, x=lambda_list))**2 / np.trapz(emiss_bulk, x=lambda_list) / delta_lamb

print(f'FOM_LR is: {FOM_LR}')
print(f'FOM_RL is: {FOM_RL}')
print(f'FOM_RL_analytic is: {FOM_RL_analytic}')
print(f'FOM_bulk is: {FOM_bulk}')
print(f'FOM enhancement TMM is: {FOM_RL/FOM_bulk}')
print(f'FOM enhancement semi-analytical is: {FOM_RL_analytic/FOM_bulk}')
print(f'Average T is: {np.trapz(T_list_LR, x=lambda_list) / delta_lamb}')
# Out:
# FOM_LR is: 26.126674343040715
# FOM_RL is: 26.54859366862291
# FOM_RL_analytic is: 26.553249852580226
# FOM_bulk is: 26.08789067466164
# FOM enhancement TMM is: 1.0176596490573588
# FOM enhancement semi-analytical is: 1.0178381297178072
# Average T is: 0.9643932979583997

# %%
# TMM only sweep over ampiltude A, width gamma, and number of layers

#A = 0.1
#A_arr = np.arange(1, 6, 1)
A_arr = [0.1, 1, 5, 10]
print(A_arr)
#gam = 0.0005
#gam_arr = np.arange(0.0001, 0.0011, 0.0001)
gam_arr = [0.0001, 0.0005, 0.001, 0.01]
print(gam_arr)
nb = 1.7
t_prop = 0
num_stacks_arr = np.arange(1, 200, 10)
print(num_stacks_arr)
length = len(num_stacks_arr)
FOM_LR_arr = np.empty((len(A_arr), len(gam_arr), length), dtype=float)
FOM_RL_arr = np.empty((len(A_arr), len(gam_arr), length), dtype=float)
FOM_bulk_arr = np.empty((len(A_arr), len(gam_arr), length), dtype=float)

for i, A in enumerate(A_arr):
    print(f'A is: {A}')
    for j, gam in enumerate(gam_arr):
        print(f'gam is: {gam}')
        for k, n in enumerate(num_stacks_arr):
            print(f'num of stacks is: {n}')
            n_list, d_list, c_list, losses_total = generate_StackofStacks(gam, A, nb, n, t_prop)
            n_list_reversed = n_list[::-1]
            d_list_reversed = d_list[::-1]
            c_list_reversed = c_list[::-1]

            T_list_LR, R_list_LR, A_list_LR = TRA_func(n_list, d_list, c_list)
            T_list_RL, R_list_RL, A_list_RL = TRA_func(n_list_reversed, d_list_reversed, c_list_reversed)
            lambda_list = np.linspace(2,5,100)
            delta_lamb = lambda_list[-1] - lambda_list[0]
            trans_bulk = np.exp(-4*np.pi*losses_total/lambda_list)
            emiss_bulk = 1 - trans_bulk

            FOM_LR_arr[i][j][k] = (np.trapz(T_list_LR, x=lambda_list))**2 / np.trapz(A_list_LR, x=lambda_list) / delta_lamb
            FOM_RL_arr[i][j][k] = (np.trapz(T_list_RL, x=lambda_list))**2 / np.trapz(A_list_RL, x=lambda_list) / delta_lamb
            FOM_bulk_arr[i][j][k] = (np.trapz(trans_bulk, x=lambda_list))**2 / np.trapz(emiss_bulk, x=lambda_list) / delta_lamb
# Out:
# [0.1, 1, 5, 10]
# [0.0001, 0.0005, 0.001, 0.01]
# [  1  11  21  31  41  51  61  71  81  91 101 111 121 131 141 151 161 171
#  181 191]
# A is: 0.1
# gam is: 0.0001
# num of stacks is: 1
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 0.04
# k_bulk from np.sum is: 0.00023835704431003307
# total losses are: 9.534281772401322e-06
# num of stacks is: 11
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 0.44
# k_bulk from np.sum is: 0.00023835704431003307
# total losses are: 0.00010487709949641454
# num of stacks is: 21
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 0.84
# k_bulk from np.sum is: 0.00023835704431003307
# total losses are: 0.00020021991722042777
# num of stacks is: 31
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 1.24
# k_bulk from np.sum is: 0.00023835704431003307
# total losses are: 0.000295562734944441
# num of stacks is: 41
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 1.6400000000000001
# k_bulk from np.sum is: 0.00023835704431003307
# total losses are: 0.0003909055526684543
# num of stacks is: 51
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 2.04
# k_bulk from np.sum is: 0.00023835704431003307
# total losses are: 0.00048624837039246745
# num of stacks is: 61
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 2.44
# k_bulk from np.sum is: 0.00023835704431003307
# total losses are: 0.0005815911881164806
# num of stacks is: 71
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 2.84
# k_bulk from np.sum is: 0.00023835704431003307
# total losses are: 0.0006769340058404939
# num of stacks is: 81
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 3.24
# k_bulk from np.sum is: 0.00023835704431003307
# total losses are: 0.0007722768235645072
# num of stacks is: 91
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 3.64
# k_bulk from np.sum is: 0.00023835704431003307
# total losses are: 0.0008676196412885204
# num of stacks is: 101
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 4.04
# k_bulk from np.sum is: 0.00023835704431003307
# total losses are: 0.0009629624590125336
# num of stacks is: 111
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 4.44
# k_bulk from np.sum is: 0.00023835704431003307
# total losses are: 0.001058305276736547
# num of stacks is: 121
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 4.84
# k_bulk from np.sum is: 0.00023835704431003307
# total losses are: 0.00115364809446056
# num of stacks is: 131
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 5.24
# k_bulk from np.sum is: 0.00023835704431003307
# total losses are: 0.0012489909121845733
# num of stacks is: 141
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 5.64
# k_bulk from np.sum is: 0.00023835704431003307
# total losses are: 0.0013443337299085863
# num of stacks is: 151
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 6.04
# k_bulk from np.sum is: 0.00023835704431003307
# total losses are: 0.0014396765476325998
# num of stacks is: 161
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 6.44
# k_bulk from np.sum is: 0.00023835704431003307
# total losses are: 0.0015350193653566131
# num of stacks is: 171
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 6.84
# k_bulk from np.sum is: 0.00023835704431003307
# total losses are: 0.0016303621830806262
# num of stacks is: 181
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 7.24
# k_bulk from np.sum is: 0.00023835704431003307
# total losses are: 0.0017257050008046395
# num of stacks is: 191
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 7.640000000000001
# k_bulk from np.sum is: 0.00023835704431003307
# total losses are: 0.0018210478185286527
# gam is: 0.0005
# num of stacks is: 1
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 0.2
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 4.767092145632485e-05
# num of stacks is: 11
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 2.2
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 0.0005243801360195733
# num of stacks is: 21
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 4.2
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 0.0010010893505828218
# num of stacks is: 31
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 6.2
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 0.0014777985651460701
# num of stacks is: 41
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 8.200000000000001
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 0.0019545077797093187
# num of stacks is: 51
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 10.200000000000001
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 0.0024312169942725674
# num of stacks is: 61
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 12.200000000000001
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 0.0029079262088358157
# num of stacks is: 71
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 14.200000000000001
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 0.003384635423399064
# num of stacks is: 81
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 16.2
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 0.003861344637962312
# num of stacks is: 91
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 18.2
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 0.00433805385252556
# num of stacks is: 101
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 20.200000000000003
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 0.00481476306708881
# num of stacks is: 111
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 22.200000000000003
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 0.005291472281652059
# num of stacks is: 121
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 24.200000000000003
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 0.0057681814962153065
# num of stacks is: 131
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 26.200000000000003
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 0.006244890710778555
# num of stacks is: 141
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 28.200000000000003
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 0.006721599925341803
# num of stacks is: 151
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 30.200000000000003
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 0.007198309139905052
# num of stacks is: 161
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 32.2
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 0.007675018354468301
# num of stacks is: 171
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 34.2
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 0.008151727569031549
# num of stacks is: 181
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 36.2
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 0.008628436783594796
# num of stacks is: 191
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 38.2
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 0.009105145998158046
# gam is: 0.001
# num of stacks is: 1
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 0.4
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 9.53418429126497e-05
# num of stacks is: 11
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 4.4
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 0.0010487602720391466
# num of stacks is: 21
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 8.4
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 0.0020021787011656436
# num of stacks is: 31
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 12.4
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 0.0029555971302921403
# num of stacks is: 41
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 16.400000000000002
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 0.003909015559418637
# num of stacks is: 51
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 20.400000000000002
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 0.004862433988545135
# num of stacks is: 61
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 24.400000000000002
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 0.0058158524176716315
# num of stacks is: 71
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 28.400000000000002
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 0.006769270846798128
# num of stacks is: 81
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 32.4
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 0.007722689275924624
# num of stacks is: 91
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 36.4
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 0.00867610770505112
# num of stacks is: 101
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 40.400000000000006
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 0.00962952613417762
# num of stacks is: 111
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 44.400000000000006
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 0.010582944563304117
# num of stacks is: 121
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 48.400000000000006
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 0.011536362992430613
# num of stacks is: 131
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 52.400000000000006
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 0.01248978142155711
# num of stacks is: 141
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 56.400000000000006
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 0.013443199850683606
# num of stacks is: 151
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 60.400000000000006
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 0.014396618279810104
# num of stacks is: 161
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 64.4
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 0.015350036708936601
# num of stacks is: 171
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 68.4
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 0.016303455138063097
# num of stacks is: 181
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 72.4
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 0.017256873567189593
# num of stacks is: 191
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 76.4
# k_bulk from np.sum is: 0.00023835460728162421
# total losses are: 0.018210291996316092
# gam is: 0.01
# num of stacks is: 1
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 4.0
# k_bulk from np.sum is: 0.0002383534380149423
# total losses are: 0.0009534137520597692
# num of stacks is: 11
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 44.0
# k_bulk from np.sum is: 0.0002383534380149423
# total losses are: 0.010487551272657462
# num of stacks is: 21
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 84.0
# k_bulk from np.sum is: 0.0002383534380149423
# total losses are: 0.020021688793255155
# num of stacks is: 31
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 124.0
# k_bulk from np.sum is: 0.0002383534380149423
# total losses are: 0.029555826313852847
# num of stacks is: 41
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 164.0
# k_bulk from np.sum is: 0.0002383534380149423
# total losses are: 0.03908996383445054
# num of stacks is: 51
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 204.0
# k_bulk from np.sum is: 0.0002383534380149423
# total losses are: 0.04862410135504823
# num of stacks is: 61
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 244.0
# k_bulk from np.sum is: 0.0002383534380149423
# total losses are: 0.058158238875645925
# num of stacks is: 71
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 284.0
# k_bulk from np.sum is: 0.0002383534380149423
# total losses are: 0.06769237639624362
# num of stacks is: 81
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 324.0
# k_bulk from np.sum is: 0.0002383534380149423
# total losses are: 0.07722651391684131
# num of stacks is: 91
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 364.0
# k_bulk from np.sum is: 0.0002383534380149423
# total losses are: 0.086760651437439
# num of stacks is: 101
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 404.0
# k_bulk from np.sum is: 0.0002383534380149423
# total losses are: 0.0962947889580367
# num of stacks is: 111
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 444.0
# k_bulk from np.sum is: 0.0002383534380149423
# total losses are: 0.10582892647863439
# num of stacks is: 121
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 484.0
# k_bulk from np.sum is: 0.0002383534380149423
# total losses are: 0.11536306399923207
# num of stacks is: 131
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 524.0
# k_bulk from np.sum is: 0.0002383534380149423
# total losses are: 0.12489720151982978
# num of stacks is: 141
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 564.0
# k_bulk from np.sum is: 0.0002383534380149423
# total losses are: 0.13443133904042745
# num of stacks is: 151
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 604.0
# k_bulk from np.sum is: 0.0002383534380149423
# total losses are: 0.14396547656102515
# num of stacks is: 161
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 644.0
# k_bulk from np.sum is: 0.0002383534380149423
# total losses are: 0.15349961408162285
# num of stacks is: 171
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 684.0
# k_bulk from np.sum is: 0.0002383534380149423
# total losses are: 0.16303375160222053
# num of stacks is: 181
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 724.0
# k_bulk from np.sum is: 0.0002383534380149423
# total losses are: 0.17256788912281823
# num of stacks is: 191
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 764.0
# k_bulk from np.sum is: 0.0002383534380149423
# total losses are: 0.18210202664341593
# A is: 1
# gam is: 0.0001
# num of stacks is: 1
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 0.04
# k_bulk from np.sum is: 0.002386207795554136
# total losses are: 9.544831182216544e-05
# num of stacks is: 11
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 0.44
# k_bulk from np.sum is: 0.002386207795554136
# total losses are: 0.0010499314300438198
# num of stacks is: 21
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 0.84
# k_bulk from np.sum is: 0.002386207795554136
# total losses are: 0.002004414548265474
# num of stacks is: 31
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 1.24
# k_bulk from np.sum is: 0.002386207795554136
# total losses are: 0.0029588976664871288
# num of stacks is: 41
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 1.6400000000000001
# k_bulk from np.sum is: 0.002386207795554136
# total losses are: 0.003913380784708783
# num of stacks is: 51
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 2.04
# k_bulk from np.sum is: 0.002386207795554136
# total losses are: 0.004867863902930438
# num of stacks is: 61
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 2.44
# k_bulk from np.sum is: 0.002386207795554136
# total losses are: 0.005822347021152092
# num of stacks is: 71
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 2.84
# k_bulk from np.sum is: 0.002386207795554136
# total losses are: 0.006776830139373746
# num of stacks is: 81
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 3.24
# k_bulk from np.sum is: 0.002386207795554136
# total losses are: 0.007731313257595401
# num of stacks is: 91
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 3.64
# k_bulk from np.sum is: 0.002386207795554136
# total losses are: 0.008685796375817055
# num of stacks is: 101
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 4.04
# k_bulk from np.sum is: 0.002386207795554136
# total losses are: 0.009640279494038709
# num of stacks is: 111
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 4.44
# k_bulk from np.sum is: 0.002386207795554136
# total losses are: 0.010594762612260365
# num of stacks is: 121
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 4.84
# k_bulk from np.sum is: 0.002386207795554136
# total losses are: 0.011549245730482018
# num of stacks is: 131
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 5.24
# k_bulk from np.sum is: 0.002386207795554136
# total losses are: 0.012503728848703674
# num of stacks is: 141
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 5.64
# k_bulk from np.sum is: 0.002386207795554136
# total losses are: 0.013458211966925326
# num of stacks is: 151
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 6.04
# k_bulk from np.sum is: 0.002386207795554136
# total losses are: 0.014412695085146981
# num of stacks is: 161
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 6.44
# k_bulk from np.sum is: 0.002386207795554136
# total losses are: 0.015367178203368637
# num of stacks is: 171
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 6.84
# k_bulk from np.sum is: 0.002386207795554136
# total losses are: 0.01632166132159029
# num of stacks is: 181
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 7.24
# k_bulk from np.sum is: 0.002386207795554136
# total losses are: 0.017276144439811944
# num of stacks is: 191
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 7.640000000000001
# k_bulk from np.sum is: 0.002386207795554136
# total losses are: 0.0182306275580336
# gam is: 0.0005
# num of stacks is: 1
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 0.2
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.0004772396248706043
# num of stacks is: 11
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 2.2
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.0052496358735766475
# num of stacks is: 21
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 4.2
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.01002203212228269
# num of stacks is: 31
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 6.2
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.014794428370988733
# num of stacks is: 41
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 8.200000000000001
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.019566824619694778
# num of stacks is: 51
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 10.200000000000001
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.02433922086840082
# num of stacks is: 61
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 12.200000000000001
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.029111617117106862
# num of stacks is: 71
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 14.200000000000001
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.033884013365812905
# num of stacks is: 81
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 16.2
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.038656409614518945
# num of stacks is: 91
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 18.2
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.043428805863224985
# num of stacks is: 101
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 20.200000000000003
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.04820120211193104
# num of stacks is: 111
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 22.200000000000003
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.05297359836063708
# num of stacks is: 121
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 24.200000000000003
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.057745994609343126
# num of stacks is: 131
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 26.200000000000003
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.06251839085804917
# num of stacks is: 141
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 28.200000000000003
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.0672907871067552
# num of stacks is: 151
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 30.200000000000003
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.07206318335546125
# num of stacks is: 161
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 32.2
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.0768355796041673
# num of stacks is: 171
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 34.2
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.08160797585287334
# num of stacks is: 181
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 36.2
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.08638037210157938
# num of stacks is: 191
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 38.2
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.09115276835028542
# gam is: 0.001
# num of stacks is: 1
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 0.4
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.0009544792497412086
# num of stacks is: 11
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 4.4
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.010499271747153295
# num of stacks is: 21
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 8.4
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.02004406424456538
# num of stacks is: 31
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 12.4
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.029588856741977466
# num of stacks is: 41
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 16.400000000000002
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.039133649239389556
# num of stacks is: 51
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 20.400000000000002
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.04867844173680164
# num of stacks is: 61
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 24.400000000000002
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.058223234234213724
# num of stacks is: 71
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 28.400000000000002
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.06776802673162581
# num of stacks is: 81
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 32.4
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.07731281922903789
# num of stacks is: 91
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 36.4
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.08685761172644997
# num of stacks is: 101
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 40.400000000000006
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.09640240422386208
# num of stacks is: 111
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 44.400000000000006
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.10594719672127416
# num of stacks is: 121
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 48.400000000000006
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.11549198921868625
# num of stacks is: 131
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 52.400000000000006
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.12503678171609833
# num of stacks is: 141
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 56.400000000000006
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.1345815742135104
# num of stacks is: 151
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 60.400000000000006
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.1441263667109225
# num of stacks is: 161
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 64.4
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.1536711592083346
# num of stacks is: 171
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 68.4
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.16321595170574668
# num of stacks is: 181
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 72.4
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.17276074420315876
# num of stacks is: 191
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 76.4
# k_bulk from np.sum is: 0.0023861981243530213
# total losses are: 0.18230553670057084
# gam is: 0.01
# num of stacks is: 1
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 4.0
# k_bulk from np.sum is: 0.0023861754957804665
# total losses are: 0.009544701983121866
# num of stacks is: 11
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 44.0
# k_bulk from np.sum is: 0.0023861754957804665
# total losses are: 0.10499172181434052
# num of stacks is: 21
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 84.0
# k_bulk from np.sum is: 0.0023861754957804665
# total losses are: 0.2004387416455592
# num of stacks is: 31
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 124.0
# k_bulk from np.sum is: 0.0023861754957804665
# total losses are: 0.29588576147677786
# num of stacks is: 41
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 164.0
# k_bulk from np.sum is: 0.0023861754957804665
# total losses are: 0.39133278130799654
# num of stacks is: 51
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 204.0
# k_bulk from np.sum is: 0.0023861754957804665
# total losses are: 0.48677980113921515
# num of stacks is: 61
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 244.0
# k_bulk from np.sum is: 0.0023861754957804665
# total losses are: 0.5822268209704339
# num of stacks is: 71
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 284.0
# k_bulk from np.sum is: 0.0023861754957804665
# total losses are: 0.6776738408016525
# num of stacks is: 81
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 324.0
# k_bulk from np.sum is: 0.0023861754957804665
# total losses are: 0.7731208606328711
# num of stacks is: 91
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 364.0
# k_bulk from np.sum is: 0.0023861754957804665
# total losses are: 0.8685678804640898
# num of stacks is: 101
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 404.0
# k_bulk from np.sum is: 0.0023861754957804665
# total losses are: 0.9640149002953085
# num of stacks is: 111
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 444.0
# k_bulk from np.sum is: 0.0023861754957804665
# total losses are: 1.0594619201265272
# num of stacks is: 121
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 484.0
# k_bulk from np.sum is: 0.0023861754957804665
# total losses are: 1.154908939957746
# num of stacks is: 131
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 524.0
# k_bulk from np.sum is: 0.0023861754957804665
# total losses are: 1.2503559597889644
# num of stacks is: 141
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 564.0
# k_bulk from np.sum is: 0.0023861754957804665
# total losses are: 1.3458029796201831
# num of stacks is: 151
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 604.0
# k_bulk from np.sum is: 0.0023861754957804665
# total losses are: 1.4412499994514019
# num of stacks is: 161
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 644.0
# k_bulk from np.sum is: 0.0023861754957804665
# total losses are: 1.5366970192826204
# num of stacks is: 171
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 684.0
# k_bulk from np.sum is: 0.0023861754957804665
# total losses are: 1.632144039113839
# num of stacks is: 181
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 724.0
# k_bulk from np.sum is: 0.0023861754957804665
# total losses are: 1.7275910589450578
# num of stacks is: 191
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 764.0
# k_bulk from np.sum is: 0.0023861754957804665
# total losses are: 1.8230380787762763
# A is: 5
# gam is: 0.0001
# num of stacks is: 1
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 0.04
# k_bulk from np.sum is: 0.011836968250215955
# total losses are: 0.0004734787300086382
# num of stacks is: 11
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 0.44
# k_bulk from np.sum is: 0.011836968250215955
# total losses are: 0.005208266030095021
# num of stacks is: 21
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 0.84
# k_bulk from np.sum is: 0.011836968250215955
# total losses are: 0.009943053330181402
# num of stacks is: 31
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 1.24
# k_bulk from np.sum is: 0.011836968250215955
# total losses are: 0.014677840630267785
# num of stacks is: 41
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 1.6400000000000001
# k_bulk from np.sum is: 0.011836968250215955
# total losses are: 0.019412627930354167
# num of stacks is: 51
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 2.04
# k_bulk from np.sum is: 0.011836968250215955
# total losses are: 0.02414741523044055
# num of stacks is: 61
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 2.44
# k_bulk from np.sum is: 0.011836968250215955
# total losses are: 0.02888220253052693
# num of stacks is: 71
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 2.84
# k_bulk from np.sum is: 0.011836968250215955
# total losses are: 0.033616989830613314
# num of stacks is: 81
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 3.24
# k_bulk from np.sum is: 0.011836968250215955
# total losses are: 0.0383517771306997
# num of stacks is: 91
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 3.64
# k_bulk from np.sum is: 0.011836968250215955
# total losses are: 0.04308656443078608
# num of stacks is: 101
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 4.04
# k_bulk from np.sum is: 0.011836968250215955
# total losses are: 0.04782135173087246
# num of stacks is: 111
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 4.44
# k_bulk from np.sum is: 0.011836968250215955
# total losses are: 0.05255613903095885
# num of stacks is: 121
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 4.84
# k_bulk from np.sum is: 0.011836968250215955
# total losses are: 0.057290926331045225
# num of stacks is: 131
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 5.24
# k_bulk from np.sum is: 0.011836968250215955
# total losses are: 0.06202571363113161
# num of stacks is: 141
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 5.64
# k_bulk from np.sum is: 0.011836968250215955
# total losses are: 0.06676050093121798
# num of stacks is: 151
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 6.04
# k_bulk from np.sum is: 0.011836968250215955
# total losses are: 0.07149528823130437
# num of stacks is: 161
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 6.44
# k_bulk from np.sum is: 0.011836968250215955
# total losses are: 0.07623007553139076
# num of stacks is: 171
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 6.84
# k_bulk from np.sum is: 0.011836968250215955
# total losses are: 0.08096486283147714
# num of stacks is: 181
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 7.24
# k_bulk from np.sum is: 0.011836968250215955
# total losses are: 0.08569965013156353
# num of stacks is: 191
# t_KK is: 0.04
# t_inc is: 0.0
# t_total is: 7.640000000000001
# k_bulk from np.sum is: 0.011836968250215955
# total losses are: 0.0904344374316499
# gam is: 0.0005
# num of stacks is: 1
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 0.2
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.0023673827488779543
# num of stacks is: 11
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 2.2
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.0260412102376575
# num of stacks is: 21
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 4.2
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.04971503772643704
# num of stacks is: 31
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 6.2
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.07338886521521658
# num of stacks is: 41
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 8.200000000000001
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.09706269270399613
# num of stacks is: 51
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 10.200000000000001
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.12073652019277568
# num of stacks is: 61
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 12.200000000000001
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.14441034768155522
# num of stacks is: 71
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 14.200000000000001
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.16808417517033478
# num of stacks is: 81
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 16.2
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.19175800265911427
# num of stacks is: 91
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 18.2
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.21543183014789383
# num of stacks is: 101
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 20.200000000000003
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.2391056576366734
# num of stacks is: 111
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 22.200000000000003
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.26277948512545296
# num of stacks is: 121
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 24.200000000000003
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.2864533126142325
# num of stacks is: 131
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 26.200000000000003
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.31012714010301207
# num of stacks is: 141
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 28.200000000000003
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.33380096759179156
# num of stacks is: 151
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 30.200000000000003
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.3574747950805711
# num of stacks is: 161
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 32.2
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.38114862256935067
# num of stacks is: 171
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 34.2
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.4048224500581302
# num of stacks is: 181
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 36.2
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.4284962775469098
# num of stacks is: 191
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 38.2
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.4521701050356893
# gam is: 0.001
# num of stacks is: 1
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 0.4
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.004734765497755909
# num of stacks is: 11
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 4.4
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.052082420475315
# num of stacks is: 21
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 8.4
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.09943007545287408
# num of stacks is: 31
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 12.4
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.14677773043043316
# num of stacks is: 41
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 16.400000000000002
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.19412538540799226
# num of stacks is: 51
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 20.400000000000002
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.24147304038555137
# num of stacks is: 61
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 24.400000000000002
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.28882069536311045
# num of stacks is: 71
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 28.400000000000002
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.33616835034066955
# num of stacks is: 81
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 32.4
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.38351600531822855
# num of stacks is: 91
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 36.4
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.43086366029578765
# num of stacks is: 101
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 40.400000000000006
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.4782113152733468
# num of stacks is: 111
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 44.400000000000006
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.5255589702509059
# num of stacks is: 121
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 48.400000000000006
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.572906625228465
# num of stacks is: 131
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 52.400000000000006
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.6202542802060241
# num of stacks is: 141
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 56.400000000000006
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.6676019351835831
# num of stacks is: 151
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 60.400000000000006
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.7149495901611422
# num of stacks is: 161
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 64.4
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.7622972451387013
# num of stacks is: 171
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 68.4
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.8096449001162604
# num of stacks is: 181
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 72.4
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.8569925550938196
# num of stacks is: 191
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 76.4
# k_bulk from np.sum is: 0.011836913744389771
# total losses are: 0.9043402100713785
# gam is: 0.01
# num of stacks is: 1
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 4.0
# k_bulk from np.sum is: 0.011836826088243881
# total losses are: 0.047347304352975524
# num of stacks is: 11
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 44.0
# k_bulk from np.sum is: 0.011836826088243881
# total losses are: 0.5208203478827308
# num of stacks is: 21
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 84.0
# k_bulk from np.sum is: 0.011836826088243881
# total losses are: 0.994293391412486
# num of stacks is: 31
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 124.0
# k_bulk from np.sum is: 0.011836826088243881
# total losses are: 1.4677664349422412
# num of stacks is: 41
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 164.0
# k_bulk from np.sum is: 0.011836826088243881
# total losses are: 1.9412394784719964
# num of stacks is: 51
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 204.0
# k_bulk from np.sum is: 0.011836826088243881
# total losses are: 2.414712522001752
# num of stacks is: 61
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 244.0
# k_bulk from np.sum is: 0.011836826088243881
# total losses are: 2.888185565531507
# num of stacks is: 71
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 284.0
# k_bulk from np.sum is: 0.011836826088243881
# total losses are: 3.361658609061262
# num of stacks is: 81
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 324.0
# k_bulk from np.sum is: 0.011836826088243881
# total losses are: 3.8351316525910173
# num of stacks is: 91
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 364.0
# k_bulk from np.sum is: 0.011836826088243881
# total losses are: 4.3086046961207725
# num of stacks is: 101
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 404.0
# k_bulk from np.sum is: 0.011836826088243881
# total losses are: 4.782077739650528
# num of stacks is: 111
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 444.0
# k_bulk from np.sum is: 0.011836826088243881
# total losses are: 5.255550783180283
# num of stacks is: 121
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 484.0
# k_bulk from np.sum is: 0.011836826088243881
# total losses are: 5.729023826710038
# num of stacks is: 131
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 524.0
# k_bulk from np.sum is: 0.011836826088243881
# total losses are: 6.202496870239794
# num of stacks is: 141
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 564.0
# k_bulk from np.sum is: 0.011836826088243881
# total losses are: 6.675969913769549
# num of stacks is: 151
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 604.0
# k_bulk from np.sum is: 0.011836826088243881
# total losses are: 7.149442957299304
# num of stacks is: 161
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 644.0
# k_bulk from np.sum is: 0.011836826088243881
# total losses are: 7.6229160008290595
# num of stacks is: 171
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 684.0
# k_bulk from np.sum is: 0.011836826088243881
# total losses are: 8.096389044358814
# num of stacks is: 181
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 724.0
# k_bulk from np.sum is: 0.011836826088243881
# total losses are: 8.56986208788857
# num of stacks is: 191
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 764.0
# k_bulk from np.sum is: 0.011836826088243881
# total losses are: 9.043335131418324
# A is: 10
# gam is: 0.0001
# num of stacks is: 1
# t_KK is: 0.039999999999999994
# t_inc is: 0.0
# t_total is: 0.039999999999999994
# k_bulk from np.sum is: 0.023514049926560088
# total losses are: 0.0009405619970624034
# num of stacks is: 11
# t_KK is: 0.039999999999999994
# t_inc is: 0.0
# t_total is: 0.43999999999999995
# k_bulk from np.sum is: 0.023514049926560088
# total losses are: 0.010346181967686437
# num of stacks is: 21
# t_KK is: 0.039999999999999994
# t_inc is: 0.0
# t_total is: 0.8399999999999999
# k_bulk from np.sum is: 0.023514049926560088
# total losses are: 0.01975180193831047
# num of stacks is: 31
# t_KK is: 0.039999999999999994
# t_inc is: 0.0
# t_total is: 1.2399999999999998
# k_bulk from np.sum is: 0.023514049926560088
# total losses are: 0.029157421908934503
# num of stacks is: 41
# t_KK is: 0.039999999999999994
# t_inc is: 0.0
# t_total is: 1.6399999999999997
# k_bulk from np.sum is: 0.023514049926560088
# total losses are: 0.038563041879558536
# num of stacks is: 51
# t_KK is: 0.039999999999999994
# t_inc is: 0.0
# t_total is: 2.0399999999999996
# k_bulk from np.sum is: 0.023514049926560088
# total losses are: 0.047968661850182566
# num of stacks is: 61
# t_KK is: 0.039999999999999994
# t_inc is: 0.0
# t_total is: 2.4399999999999995
# k_bulk from np.sum is: 0.023514049926560088
# total losses are: 0.0573742818208066
# num of stacks is: 71
# t_KK is: 0.039999999999999994
# t_inc is: 0.0
# t_total is: 2.8399999999999994
# k_bulk from np.sum is: 0.023514049926560088
# total losses are: 0.06677990179143063
# num of stacks is: 81
# t_KK is: 0.039999999999999994
# t_inc is: 0.0
# t_total is: 3.2399999999999993
# k_bulk from np.sum is: 0.023514049926560088
# total losses are: 0.07618552176205466
# num of stacks is: 91
# t_KK is: 0.039999999999999994
# t_inc is: 0.0
# t_total is: 3.6399999999999992
# k_bulk from np.sum is: 0.023514049926560088
# total losses are: 0.0855911417326787
# num of stacks is: 101
# t_KK is: 0.039999999999999994
# t_inc is: 0.0
# t_total is: 4.039999999999999
# k_bulk from np.sum is: 0.023514049926560088
# total losses are: 0.09499676170330273
# num of stacks is: 111
# t_KK is: 0.039999999999999994
# t_inc is: 0.0
# t_total is: 4.4399999999999995
# k_bulk from np.sum is: 0.023514049926560088
# total losses are: 0.10440238167392678
# num of stacks is: 121
# t_KK is: 0.039999999999999994
# t_inc is: 0.0
# t_total is: 4.839999999999999
# k_bulk from np.sum is: 0.023514049926560088
# total losses are: 0.1138080016445508
# num of stacks is: 131
# t_KK is: 0.039999999999999994
# t_inc is: 0.0
# t_total is: 5.239999999999999
# k_bulk from np.sum is: 0.023514049926560088
# total losses are: 0.12321362161517484
# num of stacks is: 141
# t_KK is: 0.039999999999999994
# t_inc is: 0.0
# t_total is: 5.639999999999999
# k_bulk from np.sum is: 0.023514049926560088
# total losses are: 0.13261924158579885
# num of stacks is: 151
# t_KK is: 0.039999999999999994
# t_inc is: 0.0
# t_total is: 6.039999999999999
# k_bulk from np.sum is: 0.023514049926560088
# total losses are: 0.1420248615564229
# num of stacks is: 161
# t_KK is: 0.039999999999999994
# t_inc is: 0.0
# t_total is: 6.439999999999999
# k_bulk from np.sum is: 0.023514049926560088
# total losses are: 0.15143048152704694
# num of stacks is: 171
# t_KK is: 0.039999999999999994
# t_inc is: 0.0
# t_total is: 6.839999999999999
# k_bulk from np.sum is: 0.023514049926560088
# total losses are: 0.16083610149767097
# num of stacks is: 181
# t_KK is: 0.039999999999999994
# t_inc is: 0.0
# t_total is: 7.239999999999999
# k_bulk from np.sum is: 0.023514049926560088
# total losses are: 0.17024172146829503
# num of stacks is: 191
# t_KK is: 0.039999999999999994
# t_inc is: 0.0
# t_total is: 7.639999999999999
# k_bulk from np.sum is: 0.023514049926560088
# total losses are: 0.17964734143891903
# gam is: 0.0005
# num of stacks is: 1
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 0.2
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 0.004702784816338905
# num of stacks is: 11
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 2.2
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 0.05173063297972796
# num of stacks is: 21
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 4.2
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 0.09875848114311701
# num of stacks is: 31
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 6.2
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 0.14578632930650606
# num of stacks is: 41
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 8.200000000000001
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 0.19281417746989513
# num of stacks is: 51
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 10.200000000000001
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 0.2398420256332842
# num of stacks is: 61
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 12.200000000000001
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 0.2868698737966732
# num of stacks is: 71
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 14.200000000000001
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 0.3338977219600623
# num of stacks is: 81
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 16.2
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 0.3809255701234513
# num of stacks is: 91
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 18.2
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 0.42795341828684036
# num of stacks is: 101
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 20.200000000000003
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 0.4749812664502295
# num of stacks is: 111
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 22.200000000000003
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 0.5220091146136185
# num of stacks is: 121
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 24.200000000000003
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 0.5690369627770075
# num of stacks is: 131
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 26.200000000000003
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 0.6160648109403967
# num of stacks is: 141
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 28.200000000000003
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 0.6630926591037857
# num of stacks is: 151
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 30.200000000000003
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 0.7101205072671747
# num of stacks is: 161
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 32.2
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 0.7571483554305638
# num of stacks is: 171
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 34.2
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 0.8041762035939528
# num of stacks is: 181
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 36.2
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 0.8512040517573418
# num of stacks is: 191
# t_KK is: 0.2
# t_inc is: 0.0
# t_total is: 38.2
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 0.8982318999207309
# gam is: 0.001
# num of stacks is: 1
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 0.4
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 0.00940556963267781
# num of stacks is: 11
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 4.4
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 0.10346126595945591
# num of stacks is: 21
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 8.4
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 0.19751696228623403
# num of stacks is: 31
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 12.4
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 0.2915726586130121
# num of stacks is: 41
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 16.400000000000002
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 0.38562835493979025
# num of stacks is: 51
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 20.400000000000002
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 0.4796840512665684
# num of stacks is: 61
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 24.400000000000002
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 0.5737397475933464
# num of stacks is: 71
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 28.400000000000002
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 0.6677954439201246
# num of stacks is: 81
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 32.4
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 0.7618511402469026
# num of stacks is: 91
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 36.4
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 0.8559068365736807
# num of stacks is: 101
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 40.400000000000006
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 0.949962532900459
# num of stacks is: 111
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 44.400000000000006
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 1.044018229227237
# num of stacks is: 121
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 48.400000000000006
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 1.138073925554015
# num of stacks is: 131
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 52.400000000000006
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 1.2321296218807933
# num of stacks is: 141
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 56.400000000000006
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 1.3261853182075714
# num of stacks is: 151
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 60.400000000000006
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 1.4202410145343494
# num of stacks is: 161
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 64.4
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 1.5142967108611276
# num of stacks is: 171
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 68.4
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 1.6083524071879056
# num of stacks is: 181
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 72.4
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 1.7024081035146836
# num of stacks is: 191
# t_KK is: 0.4
# t_inc is: 0.0
# t_total is: 76.4
# k_bulk from np.sum is: 0.023513924081694525
# total losses are: 1.7964637998414619
# gam is: 0.01
# num of stacks is: 1
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 4.0
# k_bulk from np.sum is: 0.023513805696164847
# total losses are: 0.09405522278465939
# num of stacks is: 11
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 44.0
# k_bulk from np.sum is: 0.023513805696164847
# total losses are: 1.0346074506312533
# num of stacks is: 21
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 84.0
# k_bulk from np.sum is: 0.023513805696164847
# total losses are: 1.9751596784778471
# num of stacks is: 31
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 124.0
# k_bulk from np.sum is: 0.023513805696164847
# total losses are: 2.915711906324441
# num of stacks is: 41
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 164.0
# k_bulk from np.sum is: 0.023513805696164847
# total losses are: 3.8562641341710346
# num of stacks is: 51
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 204.0
# k_bulk from np.sum is: 0.023513805696164847
# total losses are: 4.796816362017629
# num of stacks is: 61
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 244.0
# k_bulk from np.sum is: 0.023513805696164847
# total losses are: 5.737368589864222
# num of stacks is: 71
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 284.0
# k_bulk from np.sum is: 0.023513805696164847
# total losses are: 6.677920817710817
# num of stacks is: 81
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 324.0
# k_bulk from np.sum is: 0.023513805696164847
# total losses are: 7.61847304555741
# num of stacks is: 91
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 364.0
# k_bulk from np.sum is: 0.023513805696164847
# total losses are: 8.559025273404004
# num of stacks is: 101
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 404.0
# k_bulk from np.sum is: 0.023513805696164847
# total losses are: 9.499577501250599
# num of stacks is: 111
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 444.0
# k_bulk from np.sum is: 0.023513805696164847
# total losses are: 10.440129729097192
# num of stacks is: 121
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 484.0
# k_bulk from np.sum is: 0.023513805696164847
# total losses are: 11.380681956943786
# num of stacks is: 131
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 524.0
# k_bulk from np.sum is: 0.023513805696164847
# total losses are: 12.321234184790379
# num of stacks is: 141
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 564.0
# k_bulk from np.sum is: 0.023513805696164847
# total losses are: 13.261786412636974
# num of stacks is: 151
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 604.0
# k_bulk from np.sum is: 0.023513805696164847
# total losses are: 14.202338640483568
# num of stacks is: 161
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 644.0
# k_bulk from np.sum is: 0.023513805696164847
# total losses are: 15.142890868330161
# num of stacks is: 171
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 684.0
# k_bulk from np.sum is: 0.023513805696164847
# total losses are: 16.083443096176754
# num of stacks is: 181
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 724.0
# k_bulk from np.sum is: 0.023513805696164847
# total losses are: 17.02399532402335
# num of stacks is: 191
# t_KK is: 4.0
# t_inc is: 0.0
# t_total is: 764.0
# k_bulk from np.sum is: 0.023513805696164847
# total losses are: 17.96454755186994

# %%
# save above results

np.save("C:\\Users\\kl89\\MS Window Project\\Data\\FOM_bulk_num1~200_A0.1,1,5,10_gam0.0001,0.0005,0.001,0.01.npy", FOM_bulk_arr)
np.save("C:\\Users\\kl89\\MS Window Project\\Data\\FOM_LR_num1~200_A0.1,1,5,10_gam0.0001,0.0005,0.001,0.01.npy", FOM_LR_arr)
np.save("C:\\Users\\kl89\\MS Window Project\\Data\\FOM_RL_num1~200_A0.1,1,5,10_gam0.0001,0.0005,0.001,0.01.npy", FOM_RL_arr)

# %%
# plot above results
color_arr = [colors.blue, colors.red, colors.green, colors.purple]
xlabel = 'Number of Stacks'
for i, A in enumerate(A_arr):
    for j, gam in enumerate(gam_arr):
        ylabel = 'Enhancement'
        gam_rounded = round(gam,4)
        savename = f'FOM_enhancement_vs_numStacks_A~{A}_gam~{gam_rounded}'
        title = f'FOM Enhancement (A={A}, x$_0$={gam_rounded})'
        fig,ax = plot_setup(xlabel,ylabel,title=title,figsize=(5,4),auto_scale=True)
        plot(fig,ax,num_stacks_arr,FOM_RL_arr[i,j,:]/FOM_bulk_arr[i,j,:],color=colors.blue, auto_scale=True)
        plt.savefig(fig_dir+savename+fmt,bbox_inches='tight',transparent=False,dpi=dpi)

        ylabel = 'FOM'
        savename = f'FOM_KK_log_vs_numStacks_A~{A}_gam~{gam_rounded}'
        title = f'Log of FOM KK (A={A}, x$_0$={gam_rounded})'
        fig,ax = plot_setup(xlabel,ylabel,title=title,figsize=(5,4),auto_scale=True)
        plot(fig,ax,num_stacks_arr,np.log(FOM_RL_arr[i,j,:]), color=colors.blue, auto_scale=True)
        plt.savefig(fig_dir+savename+fmt,bbox_inches='tight',transparent=False,dpi=dpi)

    #legend(fig,ax,auto_scale=True)
    #plt.savefig(fig_dir+savename+'legend'+fmt, bbox_inches='tight', transparent=True, dpi=dpi)

# %%
for i, A in enumerate(A_arr):
    for j, gam in enumerate(gam_arr):
        print(f"minimum for A={A}, gam={gam}: {np.argmin(FOM_RL_arr[i,j,:]/FOM_bulk_arr[i,j,:])}")
# Out:
# minimum for A=0.1, gam=0.0001: 0
# minimum for A=0.1, gam=0.0005: 19
# minimum for A=0.1, gam=0.001: 19
# minimum for A=0.1, gam=0.01: 19
# minimum for A=1, gam=0.0001: 0
# minimum for A=1, gam=0.0005: 13
# minimum for A=1, gam=0.001: 19
# minimum for A=1, gam=0.01: 19
# minimum for A=5, gam=0.0001: 0
# minimum for A=5, gam=0.0005: 3
# minimum for A=5, gam=0.001: 6
# minimum for A=5, gam=0.01: 19
# minimum for A=10, gam=0.0001: 0
# minimum for A=10, gam=0.0005: 1
# minimum for A=10, gam=0.001: 3
# minimum for A=10, gam=0.01: 19
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Semi-analytical sweep over ampiltude A, width gamma, and number of layers
# to compare and debug above calculation

#A = 0.1
A_arr = np.arange(1, 6, 1)
print(A_arr)
#gam = 0.0005
gam_arr = np.arange(0.0001, 0.0011, 0.0001)
print(gam_arr)
nb = 1.7
t_prop = 0
num_stacks_arr = np.arange(1, 52, 5)
print(num_stacks_arr)
length = len(num_stacks_arr)
FOM_LR_arr_analytic = np.empty((len(A_arr), len(gam_arr), length), dtype=float)
FOM_RL_arr_analytic = np.empty((len(A_arr), len(gam_arr), length), dtype=float)
FOM_bulk_arr_analytic = np.empty((len(A_arr), len(gam_arr), length), dtype=float)

for i, A in enumerate(A_arr):
    print(f'A is: {A}')
    for j, gam in enumerate(gam_arr):
        print(f'gam is: {gam}')

        n_list_KK, d_list_KK = generate_n_and_d(gam, A, nb, False)
        c_list_KK = []
        for m in range(len(d_list_KK)):
            c_list_KK.append('c')

        t_KK = np.sum(d_list_KK)
        t_inc = t_prop*t_KK
        print(f"t_KK is: {t_KK}")
        print(f"t_inc is: {t_inc}")
        k_bulk = np.sum(d_list_KK * np.imag(n_list_KK)) / t_KK
        print(f'k_bulk from np.sum is: {k_bulk}')

        d_list_KK.append(inf)
        d_list_KK.insert(0, inf)
        n_list_KK.append(nb)
        n_list_KK.insert(0, nb)
        c_list_KK.insert(0, 'i')
        c_list_KK.append('i')
        
        n_list_reversed_KK = n_list_KK[::-1]
        d_list_reversed_KK = d_list_KK[::-1]
        c_list_reversed_KK = c_list_KK[::-1]


        T_list_LR_KK, R_list_LR_KK, A_list_LR_KK = TRA_func(n_list_KK, d_list_KK, c_list_KK)
        T_list_RL_KK, R_list_RL_KK, A_list_RL_KK = TRA_func(n_list_reversed_KK, d_list_reversed_KK, c_list_reversed_KK)

        for k, n in enumerate(num_stacks_arr):
            print(f'num of stacks is: {n}')

            t_total = n*(t_inc + t_KK)
            print(f"t_total is: {t_total}")
            losses_total = t_total * k_bulk
            print(f'total losses are: {losses_total}')
            
            T_list_analytic = T_list_LR_KK**n
            geom_series = np.zeros_like(A_list_LR_KK)
            for l in range(n):
                geom_series = geom_series + T_list_LR_KK**l
                
            A_list_LR_analytic = A_list_LR_KK*geom_series
            A_list_RL_analytic = A_list_RL_KK*geom_series

            #######################################################################

            lambda_list = np.linspace(2,5,100)
            delta_lamb = lambda_list[-1] - lambda_list[0]
            trans_bulk = np.exp(-4*np.pi*losses_total/lambda_list)
            emiss_bulk = 1 - trans_bulk

            FOM_LR_arr_analytic[i][j][k] = (np.trapz(T_list_analytic, x=lambda_list))**2 / np.trapz(A_list_LR_analytic, x=lambda_list) / delta_lamb
            FOM_RL_arr_analytic[i][j][k] = (np.trapz(T_list_analytic, x=lambda_list))**2 / np.trapz(A_list_RL_analytic, x=lambda_list) / delta_lamb
            FOM_bulk_arr_analytic[i][j][k] = (np.trapz(trans_bulk, x=lambda_list))**2 / np.trapz(emiss_bulk, x=lambda_list) / delta_lamb

# %%
# save above results

np.save("C:\\Users\\kl89\\MS Window Project\\Data\\FOM_bulk_analytic_num1~50_A0-1~5_gam0-0001~0.001.npy", FOM_bulk_arr_analytic)
np.save("C:\\Users\\kl89\\MS Window Project\\Data\\FOM_LR_analytic_num1~50_A0-1~5_gam0-0001~0.001.npy", FOM_LR_arr_analytic)
np.save("C:\\Users\\kl89\\MS Window Project\\Data\\FOM_RL_analytic_num1~50_A0-1~5_gam0-0001~0.001.npy", FOM_RL_arr_analytic)

# %%
savename = f'FOM_RL_and_bulk_vs_numStacks_A~5_gam~0.001_TMM_vs_analytical'
xlabel = 'Number of Stacks'; ylabel = 'Enhancement'
title = f'FOM (A=5, x$_0$=0.001)'
fig,ax = plot_setup(xlabel,ylabel,title=title,figsize=(5,4),auto_scale=True)
j = len(A_arr)-1
i = len(gam_arr)-1
plot(fig,ax,num_stacks_arr,FOM_RL_arr[j,i,:], label=f'KK,TMM', color=colors.blue,auto_scale=True)
plot(fig,ax,num_stacks_arr,FOM_RL_arr_analytic[j,i,:], label=f'KK,Analytic', color=colors.green,auto_scale=True)
plot(fig,ax,num_stacks_arr,FOM_bulk_arr[j,i,:], '--', label=f'bulk,TMM', color=colors.light_blue,auto_scale=True)
plot(fig,ax,num_stacks_arr,FOM_bulk_arr_analytic[j,i,:], '--', label=f'bulk,Analytic', color=colors.light_green,auto_scale=True)
plt.savefig(fig_dir+savename+fmt,bbox_inches='tight',transparent=False,dpi=dpi)
legend(fig,ax,auto_scale=True) # create legend from curves labeled above
plt.savefig(fig_dir+savename+'legend'+fmt, bbox_inches='tight', transparent=True, dpi=dpi) # save legend as image file

# %%
for i, gam in enumerate(gam_arr):
    savename = f'FOMEnhancement_vs_numStacks_and_A_gam~{round(gam, 4)}_pureTMM'
    xlabel = 'Number of Stacks'; ylabel = 'Enhancement'
    title = f'FOM Enhancement (x$_0$={gam})'
    fig,ax = plot_setup(xlabel,ylabel,title=title,figsize=(5,4),auto_scale=True)
    for j, A in enumerate(A_arr):
        plot(fig,ax,num_stacks_arr,FOM_RL_arr[j,i,:]/FOM_bulk_arr[j,i,:], label=f'A={A}',auto_scale=True)

    legend(fig,ax,auto_scale=True) # create legend from curves labeled above
    plt.savefig(fig_dir+savename+'legend'+fmt, bbox_inches='tight', transparent=True, dpi=dpi) # save legend as image file
    plt.savefig(fig_dir+savename+fmt,bbox_inches='tight',transparent=False,dpi=dpi)

# %%
# plot above results

for i, gam in enumerate(gam_arr):
    plt.figure()
    for j, A in enumerate(A_arr):
        plt.plot(num_stacks_arr, FOM_RL_arr_analytic[j,i,:]/FOM_bulk_arr_analytic[j,i,:], label=f'A={A}')
    plt.ylabel('Enhancement')
    plt.xlabel('Number of Stacks')
    plt.title(f'FOM Enhancement for x0 = {round(gam, 4)}')
    plt.legend(loc='lower left')
    plt.savefig(f"C:\\Users\\kl89\\MS Window Project\\Figures\\FOM_vs_numStacks_and_A_gam~{round(gam, 4)}_semi-analytical.png")

# %%
# only for when sweeping A, gam, and num_stacks

for i, gam in enumerate(gam_arr): 
    plt.figure(i)
    for j, A in enumerate(A_arr):
        plt.plot(num_stacks_arr, FOM_RL_arr_analytic[j, i, :], '*-', label=f'KK, A={A}')
        plt.plot(num_stacks_arr, FOM_bulk_arr_analytic[j, i, :], '*-', label=f'bulk, A={A}')
    plt.title(f"FOM Enhancement (x0 = {round(gam, 4)})")
    plt.legend(loc='upper right')
    plt.xlabel("number of stacks")
    plt.ylabel('enhancement')

# %%
# Semi-analytical sweep over amplitude A and number of layers N (fix gamma)

gam = 0.0002
#A = 0.1
A_arr = np.arange(1, 100, 1)
#gam_arr = np.arange(0.0001, 0.0011, 0.0001)
#print(gam_arr)
nb = 1.7
t_prop = 0
num_stacks_arr = np.arange(1, 1000, 1)
length = len(num_stacks_arr)
FOM_LR_arr_analytic = np.empty((len(A_arr), length), dtype=float)
FOM_RL_arr_analytic = np.empty((len(A_arr), length), dtype=float)
FOM_bulk_arr_analytic = np.empty((len(A_arr), length), dtype=float)

for i, A in enumerate(A_arr):
    print(f'A is: {A}')

    n_list_KK, d_list_KK = generate_n_and_d(gam, A, nb, False)
    c_list_KK = []
    for m in range(len(d_list_KK)):
        c_list_KK.append('c')

    t_KK = np.sum(d_list_KK)
    t_inc = t_prop*t_KK
    print(f"t_KK is: {t_KK}")
    print(f"t_inc is: {t_inc}")
    k_bulk = np.sum(d_list_KK * np.imag(n_list_KK)) / t_KK
    print(f'k_bulk from np.sum is: {k_bulk}')

    d_list_KK.append(inf)
    d_list_KK.insert(0, inf)
    n_list_KK.append(nb)
    n_list_KK.insert(0, nb)
    c_list_KK.insert(0, 'i')
    c_list_KK.append('i')
    
    n_list_reversed_KK = n_list_KK[::-1]
    d_list_reversed_KK = d_list_KK[::-1]
    c_list_reversed_KK = c_list_KK[::-1]


    T_list_LR_KK, R_list_LR_KK, A_list_LR_KK = TRA_func(n_list_KK, d_list_KK, c_list_KK)
    T_list_RL_KK, R_list_RL_KK, A_list_RL_KK = TRA_func(n_list_reversed_KK, d_list_reversed_KK, c_list_reversed_KK)

    for j, n in enumerate(num_stacks_arr):
        print(f'num of stacks is: {n}')

        t_total = n*(t_inc + t_KK)
        print(f"t_total is: {t_total}")
        losses_total = t_total * k_bulk
        print(f'total losses are: {losses_total}')
        
        T_list_analytic = T_list_LR_KK**n
        geom_series = np.zeros_like(A_list_LR_KK)
        for l in range(n):
            geom_series = geom_series + T_list_LR_KK**l
            
        A_list_LR_analytic = A_list_LR_KK*geom_series
        A_list_RL_analytic = A_list_RL_KK*geom_series

        #######################################################################

        lambda_list = np.linspace(2,5,100)
        delta_lamb = lambda_list[-1] - lambda_list[0]
        trans_bulk = np.exp(-4*np.pi*losses_total/lambda_list)
        emiss_bulk = 1 - trans_bulk

        FOM_LR_arr_analytic[i][j] = (np.trapz(T_list_analytic, x=lambda_list))**2 / np.trapz(A_list_LR_analytic, x=lambda_list) / delta_lamb
        FOM_RL_arr_analytic[i][j] = (np.trapz(T_list_analytic, x=lambda_list))**2 / np.trapz(A_list_RL_analytic, x=lambda_list) / delta_lamb
        FOM_bulk_arr_analytic[i][j] = (np.trapz(trans_bulk, x=lambda_list))**2 / np.trapz(emiss_bulk, x=lambda_list) / delta_lamb

# %%
np.save("C:\\Users\\kl89\\MS Window Project\\Data\\FOM_bulk_analytic_fixed_StackofStacks_num1~1000_A0-1~100_gam0-0002.npy", FOM_bulk_arr_analytic)
np.save("C:\\Users\\kl89\\MS Window Project\\Data\\FOM_LR_analytic_fixed_StackofStacks_num1~1000_A0-1~100_gam0-0002.npy", FOM_LR_arr_analytic)
np.save("C:\\Users\\kl89\\MS Window Project\\Data\\FOM_RL_analytic_fixed_StackofStacks_num1~1000_A0-1~100_gam0-0002.npy", FOM_RL_arr_analytic)

# %%
# Plot enhancement as a colorplot

plt.figure()
plt.imshow(np.log(FOM_RL_arr_analytic/FOM_bulk_arr_analytic), interpolation='none', aspect='auto', origin='lower', extent=[num_stacks_arr[0], num_stacks_arr[-1],
    A_arr[0], A_arr[-1]])
plt.colorbar(label="log(FoM)")
plt.ylabel('Amplitude A')
plt.xlabel('Number of Stacks')
plt.title('Log of FoM Enhancement (gamma=0.0002)')
# Out:
# Text(0.5, 1.0, 'Log of FoM Enhancement (gamma=0.0002)')

# %%
# Plot enhancement against num stacks for set A

A_set = 1
plt.figure()
plt.plot(num_stacks_arr, np.log(FOM_RL_arr_analytic[A_set, :] / FOM_bulk_arr_analytic[A_set, :]))
plt.ylabel('Log of Enhancement')
plt.xlabel('Number of Stacks N')
plt.title(f'Log of FoM Enhancement (gamma=0.0002), A={A_set}')

# %%
# Plot enhancement against A for set num stacks

num_stacks_set = 500

plt.figure()
plt.plot(A_arr, np.log(FOM_RL_arr_analytic[:, num_stacks_set] / FOM_bulk_arr_analytic[:, num_stacks_set]))
plt.ylabel('Log of Enhancement')
plt.xlabel('Amplitude A')
plt.title(f'Log of FoM Enhancement (gamma=0.001), num_stacks={num_stacks_set}')

# %%
# Color Plot of Number of Stacks vs. FOM and A

plt.figure()
#plt.imshow(np.log(FOM_RL_arr_analytic/FOM_bulk_arr_analytic), interpolation='none', aspect='auto', origin='lower')
ratio = np.log(FOM_RL_arr_analytic / FOM_bulk_arr_analytic)

# Create arrays for x (i values), y (FOM[i][j] values), and color (j values)
x = np.repeat(np.arange(ratio.shape[0]), ratio.shape[1])  # Repeat i for each j
y = ratio.flatten()  # Flatten the array to get the FOM[i][j] values
colors = np.tile(np.arange(ratio.shape[1]), ratio.shape[0])  # Repeat j for each i

# Plot using scatter with colors representing j
plt.scatter(x, y, c=colors, cmap='viridis', marker='.')
plt.colorbar(label="Number of Stacks")  # Colorbar shows the index j

# Set labels
plt.xlabel("Amplitude A")
plt.ylabel("Log of FoM Enhancement")
plt.title("Number of Stacks Needed Given an FoM and Amplitude")
# Out:
# Text(0.5, 1.0, 'Number of Stacks Needed Given an FoM and Amplitude')

# %%
############################ SINGLE CONTOUR PLOT CODE ###########################

plt.figure()
# Assuming FOM_RL_arr_analytic and FOM_bulk_arr_analytic are your 2D arrays
FOM = np.log(FOM_RL_arr_analytic / FOM_bulk_arr_analytic)

# Interpolate FOM[i][j] for a specific FOM value (e.g., FOM = 2)
desired_FOM = 0.1
# Initialize a list to store the N values for the desired FOM
N_values_for_FOM = []

# Iterate through each value of A and find the closest N that gives the desired FOM
for a in A_arr:
    # Find the index of the closest FOM value to the desired FOM
    idx = np.argmin(np.abs(FOM[int((a - A_arr[0]) / (A_arr[1] - A_arr[0]))] - desired_FOM))
    N_values_for_FOM.append(num_stacks_arr[idx])

plt.plot(A_arr, N_values_for_FOM)
plt.xlabel("Amplitude A")
plt.ylabel("Number of stacks N")
plt.title(f"log(FoM) = {desired_FOM}")
plt.grid(True)
plt.show()

# %%
#################### CONTOUR PLOT CODE ##############################

# Assuming FOM_RL_arr_analytic and FOM_bulk_arr_analytic are your 2D arrays
FOM = FOM_RL_arr_analytic / FOM_bulk_arr_analytic

# Create a meshgrid for the contour plot
A_grid, N_grid = np.meshgrid(A_arr, num_stacks_arr)

FOM_transposed = FOM.T

# Create an inverted contour plot: contour levels will correspond to N values
plt.figure(figsize=(10, 8))

# Use 'contour' to plot the contours, and we set levels to correspond to specific N values
# We will create the contours for FOM values, but the color scale will correspond to N values.
# We assume FOM[i, j] corresponds to FOM at (A[i], N[j])

# Plot contours for specific FOM levels (can be adjusted as needed)
print(np.min(FOM_transposed))
contour = plt.contour(A_grid, N_grid, FOM_transposed, levels=np.linspace(np.min(FOM_transposed), np.max(FOM_transposed), 20), cmap='viridis')

# Add labels and title
plt.xlabel('Amplitude (A)')
plt.ylabel('Number of Stacks (N)')
plt.title('Contour Plot of Constant FoM Enhancement')

# Optional: Add a color bar to show the mapping between contour levels and N values
plt.colorbar(contour, label="FoM")

plt.grid(True)
plt.show()
# Out:
# 1.00000881757174

# %%
for i, A in enumerate(A_arr):
    print(FOM_RL_arr[i][0]/FOM_bulk_arr[i][0])
    print(FOM_RL_arr[i][1]/FOM_bulk_arr[i][1])
    plt.plot(num_stacks_arr, FOM_RL_arr[i]/FOM_bulk_arr[i], '-*', label=f'A={A}')
plt.title('FoM Enhancement (x0 = 0.0005)')
plt.xlabel('Number of Stacks')
plt.ylabel('Enhancement')
plt.legend(loc='upper right')
# Out:
# 1.0007050266240705
# 1.0007043086154523
# 1.001133790222959
# 1.0011323663431653
# 1.0015668604261156
# 1.001564946591341
# 1.0020042248924506
# 1.0020023766379318
# 1.0024458687768019
# 1.0024449761121026

# %%
plt.plot(FOM_RL_arr/FOM_bulk_arr, label='RL to bulk')
#plt.plot(FOM_RL_arr/FOM_bulk_arr, label='RL to bulk')
#plt.plot(FOM_RL_arr/FOM_bulk_arr, label='RL to bulk')
#plt.plot(FOM_LR_arr/FOM_bulk_arr, label='LR to bulk')
#plt.plot(FOM_RL_arr/FOM_LR_arr, label='RL to LR')
plt.title('Ratio of FOMs')
plt.xlabel('Number of Stacks')
plt.ylabel('Ratio')
plt.legend()
print(FOM_RL_arr)

# %%
np.save("C:\\Users\\kl89\\MS Window Project\\FOM_bulk_StackofStacks_num1~50_A1~5_gam0-0001~0-001.npy", FOM_bulk_arr)
np.save("C:\\Users\\kl89\\MS Window Project\\FOM_LR_StackofStacks_num1~50_A1~5_gam0-0001~0-001.npy", FOM_LR_arr)
np.save("C:\\Users\\kl89\\MS Window Project\\FOM_RL_StackofStacks_num1~50_A1~5_gam0-0001~0-001.npy", FOM_RL_arr)

# %%
arr = np.array([1, 3, 5, 7, 9])

midpoints = (arr[:-1] + arr[1:]) / 2

print(arr[0:-1])
# Out:
# [1 3 5 7]
